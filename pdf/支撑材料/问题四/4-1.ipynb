# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.sans-serif']='SimHei'
plt.rcParams['axes.unicode_minus']=False
# 计算高钾和铅钡的pearson系数
data1 = pd.read_excel('work4.xlsx')
data2 = pd.read_excel('work5.xlsx')

# %%
print(data.corr())
# Out:
#              二氧化硅(SiO2)  氧化钠(Na2O)  氧化钾(K2O)  氧化钙(CaO)  氧化镁(MgO)  氧化铝(Al2O3)  \
# 二氧化硅(SiO2)     1.000000  -0.457198 -0.876793 -0.822889 -0.602978   -0.830732
# 氧化钠(Na2O)     -0.457198   1.000000  0.554220  0.620628 -0.244731    0.344563
# 氧化钾(K2O)      -0.876793   0.554220  1.000000  0.759379  0.386963    0.590856
# 氧化钙(CaO)      -0.822889   0.620628  0.759379  1.000000  0.205060    0.536369
# 氧化镁(MgO)      -0.602978  -0.244731  0.386963  0.205060  1.000000    0.697763
# 氧化铝(Al2O3)    -0.830732   0.344563  0.590856  0.536369  0.697763    1.000000
# 氧化铁(Fe2O3)    -0.687378  -0.023046  0.335781  0.457084  0.594784    0.689465
# 氧化铜(CuO)      -0.465189  -0.022229  0.250670  0.423472  0.140693    0.209659
# 氧化铅(PbO)      -0.398057   0.359165  0.275214  0.367660  0.166376    0.422439
# 氧化钡(BaO)      -0.344856  -0.213569  0.092629  0.078330  0.427346    0.380576
# 五氧化二磷(P2O5)   -0.447796  -0.185782  0.171173 -0.031251  0.650444    0.676068
# ...
